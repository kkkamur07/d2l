# %%
# %matplotlib inline
import math
import time
import numpy as np
import torch
from d2l import torch as d2l

# %%
# Vectorization
n = 10000
a = torch.ones(n)
b = torch.ones(n)

# Commands being equivalent
c = torch.zeros(n)
t = time.time()

for i in range(n):
    c[i] = a[i] + b[i]
print(f'For loop time : {time.time() - t:.5f}')

# Vectorized version
t = time.time()
c = a + b
print(f'Vectorized time : {time.time() - t:.5f}')
# Out:
# For loop time : 0.11125
# Vectorized time : 0.00023

# %%
# Playing with normal

def normal(x, mu, sigma):
    denom = (1 / (np.sqrt(2 * torch.pi) * sigma))
    return  denom * torch.exp(-((x - mu) ** 2) / (2 * sigma ** 2))

# Visualization
x = torch.arange(-7, 7, 0.01)
params = torch.tensor([[0, 1], [0, 3], [3, 2]])
d2l.plot(x, [normal(x,mu,sigma) for mu, sigma in params], xlabel='x', ylabel='p(x)', legend=[f'mu={mu}, sigma={sigma}' for mu, sigma in params], xlim=[-7, 7], ylim=[0, 0.5])
